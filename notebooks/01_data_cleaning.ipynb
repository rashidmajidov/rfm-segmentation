# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format

# %%
df_dirty = pd.read_csv(r'C:\Users\rashid\Desktop\sample-sales-data\data\raw\sales_data_sample.csv', encoding='latin1')
df = df_dirty.copy()
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2 2871.00
# 1        10121               34      81.35                5 2765.90
# 2        10134               41      94.74                2 3884.34
# 3        10145               45      83.26                6 3746.70
# 4        10159               49     100.00               14 5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  Motorcycles    95
# 1    5/7/2003 0:00  Shipped       2         5     2003  Motorcycles    95
# 2    7/1/2003 0:00  Shipped       3         7     2003  Motorcycles    95
# 3   8/25/2003 0:00  Shipped       3         8     2003  Motorcycles    95
# 4  10/10/2003 0:00  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# ...

# %% [markdown]
# ## 📊 Dataset Metadata: `sales_data_sample.csv`
#
# | Xüsusiyyət | Dəyər |
# |---|---|
# | **Mənbə** | [Kaggle - Sample Sales Data](https://www.kaggle.com/datasets/kyanyoga/sample-sales-data) |
# | **Sətir sayı** | 2823 |
# | **Sütun sayı** | 25 |
# | **Encoding** | latin1 |
# | **Tarix aralığı** | 01/10/2003 – 09/09/2004 |
# | **İllər** | 2003, 2004, 2005 |
#
# ### Sütunların təsviri
#
# | Sütun | Tip | Boş dəyər | Unikal | Təsvir |
# |---|---|---|---|---|
# | `ORDERNUMBER` | int | 0 | 307 | Sifariş ID |
# | `QUANTITYORDERED` | int | 0 | 58 | Sifariş miqdarı |
# | `PRICEEACH` | float | 0 | 1016 | Vahid qiymət |
# | `ORDERLINENUMBER` | int | 0 | 18 | Sifariş sətir nömrəsi |
# | `SALES` | float | 0 | 2763 | Ümumi satış məbləği |
# | `ORDERDATE` | datetime | 0 | 252 | Sifariş tarixi |
# | `STATUS` | category | 0 | 6 | Shipped, Disputed, In Process, Cancelled, On Hold, Resolved |
# | `QTR_ID` | int | 0 | 4 | Rüb (1–4) |
# | `MONTH_ID` | int | 0 | 12 | Ay |
# | `YEAR_ID` | int | 0 | 3 | 2003, 2004, 2005 |
# | `PRODUCTLINE` | category | 0 | 7 | Motorcycles, Classic Cars, Trucks and Buses, Vintage Cars, Planes, Ships, Trains |
# | `MSRP` | int | 0 | 80 | Tövsiyə olunan pərakəndə qiymət |
# | `PRODUCTCODE` | str | 0 | 109 | Məhsul kodu |
# | `CUSTOMERNAME` | str | 0 | 92 | Müştəri adı |
# | `PHONE` | str | 0 | 91 | Telefon |
# | `ADDRESSLINE1` | str | 0 | 92 | Ünvan sətri 1 |
# | `ADDRESSLINE2` | str | 2521 | 9 | Ünvan sətri 2 |
# | `CITY` | str | 0 | 73 | Şəhər |
# | `STATE` | str | 1486 | 16 | Əyalət/vilayət |
# | `POSTALCODE` | str | 76 | 73 | Poçt kodu |
# | `COUNTRY` | category | 0 | 19 | Ölkə |
# | `TERRITORY` | category | 1074 | 4 | EMEA, APAC, Japan |
# | `CONTACTLASTNAME` | str | 0 | 77 | Kontakt soyadı |
# | `CONTACTFIRSTNAME` | str | 0 | 72 | Kontakt adı |
# | `DEALSIZE` | category | 0 | 3 | Small, Medium, Large |
#
# > ⚠️ **Qeyd:** `ADDRESSLINE2`, `STATE`, `POSTALCODE` və `TERRITORY` sütunlarında xeyli sayda boş (`NaN`) dəyər mövcuddur.

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   str
#  6   STATUS            2823 non-null   str
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   str
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   str
#  13  CUSTOMERNAME      2823 non-null   str
#  14  PHONE             2823 non-null   str
#  15  ADDRESSLINE1      2823 non-null   str
#  16  ADDRESSLINE2      302 non-null    str
# ...

# %%
df.describe()
# Out:
#        ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# count      2823.00          2823.00    2823.00          2823.00  2823.00
# mean      10258.73            35.09      83.66             6.47  3553.89
# std          92.09             9.74      20.17             4.23  1841.87
# min       10100.00             6.00      26.88             1.00   482.13
# 25%       10180.00            27.00      68.86             3.00  2203.43
# 50%       10262.00            35.00      95.70             6.00  3184.80
# 75%       10333.50            43.00     100.00             9.00  4508.00
# max       10425.00            97.00     100.00            18.00 14082.80
#
#        QTR_ID  MONTH_ID  YEAR_ID    MSRP
# count 2823.00   2823.00  2823.00 2823.00
# mean     2.72      7.09  2003.82  100.72
# std      1.20      3.66     0.70   40.19
# min      1.00      1.00  2003.00   33.00
# 25%      2.00      4.00  2003.00   68.00
# 50%      3.00      8.00  2004.00   99.00
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["ORDERDATE"] = pd.to_datetime(df["ORDERDATE"])

# %%
#ADDRESSLINE2
df['ADDRESSLINE2'] = df["ADDRESSLINE2"].fillna("Not Provided")

# %%
#STATE
df['STATE'].value_counts()
# Out:
# STATE
# CA               416
# MA               190
# NY               178
# NSW               92
# Victoria          78
# PA                75
# CT                61
# BC                48
# NH                34
# Tokyo             32
# NV                29
# Isle of Wight     26
# Quebec            22
# NJ                21
# Osaka             20
# Queensland        15
# Name: count, dtype: int64

# %%
df[(df['STATE'].isna()) & (df['COUNTRY'] == 'USA')]
# Out:
# Empty DataFrame
# Columns: [ORDERNUMBER, QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CUSTOMERNAME, PHONE, ADDRESSLINE1, ADDRESSLINE2, CITY, STATE, POSTALCODE, COUNTRY, TERRITORY, CONTACTLASTNAME, CONTACTFIRSTNAME, DEALSIZE]
# Index: []

# %%
df['STATE'] = df['STATE'].fillna('Not Applicable')

# %%
#POSTALCODE
dfp = df[df["POSTALCODE"].isna()]
dfp.shape
# Out:
# (76, 25)

# %%
#demeli sadece 3 şəxsə aid məlumatlar var.
dfp["PHONE"].value_counts()
# Out:
# PHONE
# 6505551386    41
# 6505555787    21
# 2155554369    14
# Name: count, dtype: int64

# %%
#Bu cur de baxsaq California ştatının postal kodu 94217di
dfp['STATE'].value_counts()
# Out:
# STATE
# CA    76
# Name: count, dtype: int64

# %%
dfp['ADDRESSLINE1'].value_counts()
"""
7734 Strong St. - 94217
5557 North Pendale Street - 94217
6047 Douglas Av - 94217
"""
# Out:
# '\n7734 Strong St. - 94217\n5557 North Pendale Street - 94217\n6047 Douglas Av - 94217\n'

# %%
df["POSTALCODE"] = df["POSTALCODE"].fillna('94217')

# %%
#TERRITORY
df['TERRITORY'].value_counts()
"""
EMEA - Europe, Middle East, Africa
APAC - Asia Pacific
Japan - Japan, Singapore, Philippines

"""
# Out:
# TERRITORY
# EMEA     1407
# APAC      221
# Japan     121
# Name: count, dtype: int64

# %%
df_null_territory['COUNTRY'].value_counts() 
"""
Bu ölkələr North America regionuna aid olduğu üçün TERRITORY sütununa NA dəyəri verəcəm
"""
# Out:
# COUNTRY
# USA       1004
# Canada      70
# Name: count, dtype: int64

# %%
df['TERRITORY'] = df['TERRITORY'].fillna('NA')

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2 2871.00
# 1        10121               34      81.35                5 2765.90
# 2        10134               41      94.74                2 3884.34
# 3        10145               45      83.26                6 3746.70
# 4        10159               49     100.00               14 5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0 2003-02-24  Shipped       1         2     2003  Motorcycles    95
# 1 2003-05-07  Shipped       2         5     2003  Motorcycles    95
# 2 2003-07-01  Shipped       3         7     2003  Motorcycles    95
# 3 2003-08-25  Shipped       3         8     2003  Motorcycles    95
# 4 2003-10-10  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# ...

# %%
df.to_csv(r'C:\Users\rashid\Desktop\sample-sales-data\data\processed\sales_data_cleaned.csv', index=False)
